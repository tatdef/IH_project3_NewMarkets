# %% [markdown]
# # New Markets

# %%
import pandas as pd

# %% [markdown]
# ## Import the data using Pandas

# %%
df = pd.read_excel("5_New_markets.xlsx")
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
# [2627 rows x 10 columns]

# %% [markdown]
# ## Examine the data for potential issues (missing data, data inconsistency, outliers, duplicates etc)

# %%
len(df.drop_duplicates())
# Out:
# 2627

# %%
len(df.drop_duplicates(subset='ID'))
# Out:
# 2627

# %%
df.isna().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married        50
# Age                  0
# Graduated           24
# Profession          38
# Work_Experience    269
# Spending_Score       0
# Family_Size        113
# Var_1               32
# dtype: int64

# %%
df.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    2627.000000  2627.000000      2358.000000  2514.000000
# mean   463433.918919    43.649791         2.552587     2.825378
# std      2618.245698    16.967015         3.341094     1.551906
# min    458989.000000    18.000000         0.000000     1.000000
# 25%    461162.500000    30.000000         0.000000     2.000000
# 50%    463379.000000    41.000000         1.000000     2.000000
# 75%    465696.000000    53.000000         4.000000     4.000000
# max    467968.000000    89.000000        14.000000     9.000000

# %%
df.describe(include="O")
# Out:
#        Gender Ever_Married Graduated Profession Spending_Score  Var_1
# count    2627         2577      2603       2589           2627   2595
# unique      3            2         2          9              3      7
# top      Male          Yes       Yes     Artist            Low  Cat_6
# freq     1424         1520      1602        802           1616   1672

# %% [markdown]
# ## Apply the different cleaning and manipulation techniques you have learned

# %%
from sklearn.impute import SimpleImputer, KNNImputer

# %%
list(df['Profession'].unique())
# Out:
# ['Engineer',
#  'Healthcare',
#  nan,
#  'Executive',
#  'Marketing',
#  'Doctor',
#  'Artist',
#  'Lawyer',
#  'Entertainment',
#  'Homemaker']

# %% [markdown]
# ### cleaning the culumn "Gender"

# %%
list(df['Gender'].unique())
# Out:
# ['Female', 'Male', 'female']

# %%
df['Gender'] = df['Gender'].map({'Male': 'M', 'Female': 'F', 'female': 'F'})
#df['Sex'].map({val: val[0].upper() for val in values})

# %%
list(df['Ever_Married'].unique())
# Out:
# ['Yes', 'No', nan]

# %%
list(df['Graduated'].unique())
# Out:
# ['Yes', 'No', nan]

# %%
list(df['Spending_Score'].unique())
# Out:
# ['Low', 'Average', 'High']

# %%
df['Spending_Score'].value_counts()
# Out:
# Low        1616
# Average     625
# High        386
# Name: Spending_Score, dtype: int64

# %%
df['Var_1'].value_counts()
# Out:
# Cat_6    1672
# Cat_4     386
# Cat_3     267
# Cat_2     141
# Cat_7      66
# Cat_1      34
# Cat_5      29
# Name: Var_1, dtype: int64

# %%
df.head(10)
# Out:
#        ID Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989      F          Yes   36       Yes    Engineer              0.0
# 1  458994      M          Yes   37       Yes  Healthcare              8.0
# 2  458996      F          Yes   69        No         NaN              0.0
# 3  459000      M          Yes   59        No   Executive             11.0
# 4  459001      F           No   19        No   Marketing              NaN
# 5  459003      M          Yes   47       Yes      Doctor              0.0
# 6  459005      M          Yes   61       Yes      Doctor              5.0
# 7  459008      F          Yes   47       Yes      Artist              1.0
# 8  459013      M          Yes   50       Yes      Artist              2.0
# 9  459014      M           No   19        No  Healthcare              0.0
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4            Low          4.0  Cat_6
# 5           High          5.0  Cat_4
# 6            Low          3.0  Cat_6
# 7        Average          3.0  Cat_6
# 8        Average          4.0  Cat_6
# 9            Low          4.0  Cat_6

# %% [markdown]
# ### imputing the column "Work_Experience" by the mean

# %%
df['Work_Experience'] = df['Work_Experience_Imputed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Work_Experience_Imputed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_20028/79187968.py in <module>
# ----> 1 df['Work_Experience'] = df['Work_Experience_Imputed']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Work_Experience_Imputed'

# %%
work_experience_mean = df['Work_Experience'].mean()
work_experience_mean
# Out:
# 2.552586938083121

# %%
df['Work_Experience_Imputed'] = df['Work_Experience']
df.loc[df['Work_Experience'].isna(), 'Work_Experience_Imputed'] = work_experience_mean

# %%
df
# Out:
#           ID Gender Ever_Married  Age Graduated     Profession  \
# 0     458989      F          Yes   36       Yes       Engineer
# 1     458994      M          Yes   37       Yes     Healthcare
# 2     458996      F          Yes   69        No            NaN
# 3     459000      M          Yes   59        No      Executive
# 4     459001      F           No   19        No      Marketing
# ...      ...    ...          ...  ...       ...            ...
# 2622  467954      M           No   29        No     Healthcare
# 2623  467958      F           No   35       Yes         Doctor
# 2624  467960      F           No   53       Yes  Entertainment
# 2625  467961      M          Yes   47       Yes      Executive
# 2626  467968      F           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1  \
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
#       Work_Experience_Imputed
# 0                    0.000000
# 1                    8.000000
# 2                    0.000000
# 3                   11.000000
# 4                    2.552587
# ...                       ...
# 2622                 9.000000
# 2623                 1.000000
# 2624                 2.552587
# 2625                 1.000000
# 2626                 9.000000
#
# [2627 rows x 11 columns]

# %% [markdown]
# ### imputing the column "Family_Size" by the medium (instead of by the mean)

# %%
df['Family_Size'] = df['Family_Size_Imputed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Family_Size_Imputed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_20028/1959087979.py in <module>
# ----> 1 df['Family_Size'] = df['Family_Size_Imputed']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Family_Size_Imputed'

# %%
family_size_mean = round(df['Family_Size'].mean())
family_size_mean
# Out:
# 3

# %%
family_size_median = df['Family_Size'].median()
family_size_median
# Out:
# 2.0

# %%
df['Family_Size'].value_counts()
# Out:
# 2.0    768
# 1.0    512
# 3.0    455
# 4.0    444
# 5.0    200
# 6.0     78
# 7.0     26
# 9.0     16
# 8.0     15
# Name: Family_Size, dtype: int64

# %%
df['Family_Size'].mean()
# Out:
# 2.8253778838504378

# %%
df['Family_Size_Imputed'] = df['Family_Size']
df.loc[df['Family_Size'].isna(), 'Family_Size_Imputed'] = family_size_median

# %%
df['Family_Size_Imputed'].value_counts()
# Out:
# 2.0    881
# 1.0    512
# 3.0    455
# 4.0    444
# 5.0    200
# 6.0     78
# 7.0     26
# 9.0     16
# 8.0     15
# Name: Family_Size_Imputed, dtype: int64

# %%
df
# Out:
#           ID Gender Ever_Married  Age Graduated     Profession  \
# 0     458989      F          Yes   36       Yes       Engineer
# 1     458994      M          Yes   37       Yes     Healthcare
# 2     458996      F          Yes   69        No            NaN
# 3     459000      M          Yes   59        No      Executive
# 4     459001      F           No   19        No      Marketing
# ...      ...    ...          ...  ...       ...            ...
# 2622  467954      M           No   29        No     Healthcare
# 2623  467958      F           No   35       Yes         Doctor
# 2624  467960      F           No   53       Yes  Entertainment
# 2625  467961      M          Yes   47       Yes      Executive
# 2626  467968      F           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1  \
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
#       Work_Experience_Imputed  Family_Size_Imputed
# 0                    0.000000                  1.0
# 1                    8.000000                  4.0
# 2                    0.000000                  1.0
# 3                   11.000000                  2.0
# 4                    2.552587                  4.0
# ...                       ...                  ...
# 2622                 9.000000                  4.0
# 2623                 1.000000                  1.0
# 2624                 2.552587                  2.0
# 2625                 1.000000                  5.0
# 2626                 9.000000                  3.0
#
# [2627 rows x 12 columns]

# %% [markdown]
# ### replacing missing values in culumn "Profession" by "Unknown"

# %%
df['Profession'].fillna('Unknown', inplace=True)

# %%
df['Profession'].head(20)
# Out:
# 0       Engineer
# 1     Healthcare
# 2        Unknown
# 3      Executive
# 4      Marketing
# 5         Doctor
# 6         Doctor
# 7         Artist
# 8         Artist
# 9     Healthcare
# 10    Healthcare
# 11    Healthcare
# 12        Artist
# 13    Healthcare
# 14        Doctor
# 15        Artist
# 16        Lawyer
# 17        Artist
# 18        Artist
# 19        Lawyer
# Name: Profession, dtype: object

# %%
df['Profession'].value_counts()
# Out:
# Artist           802
# Healthcare       418
# Entertainment    301
# Doctor           242
# Engineer         236
# Lawyer           221
# Executive        176
# Marketing        111
# Homemaker         82
# Unknown           38
# Name: Profession, dtype: int64

# %% [markdown]
# ### for the columns of "Ever_Married" and "Graduated"

# %%
# For the columns of "Ever_Married" and "Graduated", I first planned to use this imputation method: 
# caculate the percentage of the two values (yes or no), then assign one of the two values to 
# the people with missing age values, but the percentage of the assigned values should be 
# roughly equal to the percentage of the total existing values. But finally, We decided that 
# we can just leave them as they are and, when using the data of the column, 
# simply neglecting the missing values, since they don't occupy an important proportion.

# %% [markdown]
# ### finding the correlation between "Spending_Score" and "Family_Size"

# %%
df
# Out:
#           ID Gender Ever_Married  Age Graduated     Profession  \
# 0     458989      F          Yes   36       Yes       Engineer
# 1     458994      M          Yes   37       Yes     Healthcare
# 2     458996      F          Yes   69        No        Unknown
# 3     459000      M          Yes   59        No      Executive
# 4     459001      F           No   19        No      Marketing
# ...      ...    ...          ...  ...       ...            ...
# 2622  467954      M           No   29        No     Healthcare
# 2623  467958      F           No   35       Yes         Doctor
# 2624  467960      F           No   53       Yes  Entertainment
# 2625  467961      M          Yes   47       Yes      Executive
# 2626  467968      F           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1  \
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
#       Work_Experience_Imputed  Family_Size_Imputed
# 0                    0.000000                  1.0
# 1                    8.000000                  4.0
# 2                    0.000000                  1.0
# 3                   11.000000                  2.0
# 4                    2.552587                  4.0
# ...                       ...                  ...
# 2622                 9.000000                  4.0
# 2623                 1.000000                  1.0
# 2624                 2.552587                  2.0
# 2625                 1.000000                  5.0
# 2626                 9.000000                  3.0
#
# [2627 rows x 12 columns]

# %%
df.loc[df['amount_spent']>5840.182, 'customer_type'] = 'VIP Customer'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'amount_spent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_20028/1699524205.py in <module>
# ----> 1 df.loc[df['amount_spent']>5840.182, 'customer_type'] = 'VIP Customer'
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'amount_spent'

# %% [markdown]
# ### Export clean version of your data into CSV file using Pandas.

# %%
df
# Out:
#           ID Gender Ever_Married  Age Graduated     Profession  \
# 0     458989      F          Yes   36       Yes       Engineer
# 1     458994      M          Yes   37       Yes     Healthcare
# 2     458996      F          Yes   69        No        Unknown
# 3     459000      M          Yes   59        No      Executive
# 4     459001      F           No   19        No      Marketing
# ...      ...    ...          ...  ...       ...            ...
# 2622  467954      M           No   29        No     Healthcare
# 2623  467958      F           No   35       Yes         Doctor
# 2624  467960      F           No   53       Yes  Entertainment
# 2625  467961      M          Yes   47       Yes      Executive
# 2626  467968      F           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1  \
# 0                 0.0            Low          1.0  Cat_6
# 1                 8.0        Average          4.0  Cat_6
# 2                 0.0            Low          1.0  Cat_6
# 3                11.0           High          2.0  Cat_6
# 4                 NaN            Low          4.0  Cat_6
# ...               ...            ...          ...    ...
# 2622              9.0            Low          4.0  Cat_6
# 2623              1.0            Low          1.0  Cat_6
# 2624              NaN            Low          2.0  Cat_6
# 2625              1.0           High          5.0  Cat_4
# 2626              9.0            Low          3.0  Cat_7
#
#       Work_Experience_Imputed  Family_Size_Imputed
# 0                    0.000000                  1.0
# 1                    8.000000                  4.0
# 2                    0.000000                  1.0
# 3                   11.000000                  2.0
# 4                    2.552587                  4.0
# ...                       ...                  ...
# 2622                 9.000000                  4.0
# 2623                 1.000000                  1.0
# 2624                 2.552587                  2.0
# 2625                 1.000000                  5.0
# 2626                 9.000000                  3.0
#
# [2627 rows x 12 columns]

# %%
df.to_csv('NewMarkets_SQL.csv', sep=',', index=False)  # ',' for SQL

# %%
df.to_csv('NewMarkets_Excel.csv', sep=';', index=False)  # ';' for Excel
